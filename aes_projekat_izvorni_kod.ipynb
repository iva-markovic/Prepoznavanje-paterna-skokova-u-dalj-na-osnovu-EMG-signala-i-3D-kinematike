# %%
# projekat AES

# ucitavanje biblioteka
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import statistics as st

# %%
#jedan primer instanci podataka dobijenih sa MTw Awinda senzora
X = pd.read_csv('D_B_2_1.txt', sep="\t", header=[4])
names = X.iloc[0]
print(X)

# %%
br = 3 # ispitanik 2 
skok_2 = np.array([154, 162, 128, 134, 130, 137, 164,  150]) # skokovi ispitanika broj 2
skok_red_2 = skok_2;
skok_2 = skok_2.transpose()
j = 0
rb_2 = [0] * 8 #redni broj skoka
a_x_2 = [0] * 8
w_2 = [0] * 8
ugao_pre_2 = [0] * 8 # ugao savijanja pre skoka
ugao_posle_2 = [0] * 8 # ugao pri doskoku
for i in range(1,12):
    if (i!=1 and i!=3 and i!=5 and i!=6 and i!=11): # odabir valjanih skokova
        rb_2[j] = i
        X1 = pd.read_csv('D_B_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X2 = pd.read_csv('L_B_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X3 = pd.read_csv('D_L_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X4 = pd.read_csv('L_L_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X5 = pd.read_csv('D_R_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X6 = pd.read_csv('L_R_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        ubrz = ((abs(X1['FreeAcc_X']) + abs(X2['FreeAcc_X']) + abs(X3['FreeAcc_X']) + abs(X4['FreeAcc_X']))/4).tolist()
        a_x_2[j] = max(ubrz) # ubrzanje u smeru trostruke ekstenzije
    
        poz_max = ubrz.index(a_x_2[j]) 
        #print(poz_max)
        
        razlika_ugla1 = ((90+X1['Pitch'] - X3['Pitch'])).tolist()
        razlika_ugla2 = ((90+X2['Pitch'] - X4['Pitch'])).tolist()
        
        #ugao pre i ugao posle moze se odrediti u odnosu na trenutak maksimalnog ubrzanja
        ugao_pre_2[j] = (min(razlika_ugla1[0:poz_max])+min(razlika_ugla2[0:poz_max]))/2
        ugao_posle_2[j] = (min(razlika_ugla1[poz_max:len(razlika_ugla1)-1])+min(razlika_ugla2[poz_max:len(razlika_ugla2)-1]))/2
       
        w_2[j] = max(abs(X5['Gyr_Z']-X6['Gyr_Z'])/2) # maksimum ugaone brzine ruke; Z za desnu a -Z za levu ruku
        j = j+1

        
# dodavanje podatak van petlje zbog odredjenih nekonzistentnosti pri pamcenju podataka

X1 = pd.read_csv('D_B_'+str(4)+'_'+str(5)+'.txt', sep="\t", header=[4])
X2 = pd.read_csv('L_B_'+str(4)+'_'+str(5)+'.txt', sep="\t", header=[4])
X3 = pd.read_csv('D_L_'+str(4)+'_'+str(5)+'.txt', sep="\t", header=[4])
X4 = pd.read_csv('L_L_'+str(4)+'_'+str(5)+'.txt', sep="\t", header=[4])
X5 = pd.read_csv('D_R_'+str(4)+'_'+str(5)+'.txt', sep="\t", header=[4])
X6 = pd.read_csv('L_R_'+str(4)+'_'+str(5)+'.txt', sep="\t", header=[4])

ubrz = ((abs(X1['FreeAcc_X']) + abs(X2['FreeAcc_X']) + abs(X3['FreeAcc_X']) + abs(X4['FreeAcc_X']))/4).tolist()
a_x_2[6] = max(ubrz) # ubrzanje u smeru trostruke ekstenzije

poz_max = ubrz.index(a_x_2[6]) 
#print(poz_max)

razlika_ugla1 = ((90+X1['Pitch'] - X3['Pitch'])).tolist()
razlika_ugla2 = ((90+X2['Pitch'] - X4['Pitch'])).tolist()

#ugao pre i ugao posle moze se odrediti u odnosu na trenutak maksimalnog ubrzanja
ugao_pre_2[6] = (min(razlika_ugla1[0:poz_max])+min(razlika_ugla2[0:poz_max]))/2
ugao_posle_2[6] = (min(razlika_ugla1[poz_max:len(razlika_ugla1)-1])+min(razlika_ugla2[poz_max:len(razlika_ugla2)-1]))/2

w_2[6] = max(abs(X5['Gyr_Z']-X6['Gyr_Z'])/2) # maksimum ugaone brzine ruke; Z za desnu a -Z za levu ruku

X1 = pd.read_csv('D_B_'+str(5)+'_'+str(2)+'.txt', sep="\t", header=[4])
X2 = pd.read_csv('L_B_'+str(5)+'_'+str(2)+'.txt', sep="\t", header=[4])
X3 = pd.read_csv('D_L_'+str(5)+'_'+str(2)+'.txt', sep="\t", header=[4])
X4 = pd.read_csv('L_L_'+str(5)+'_'+str(2)+'.txt', sep="\t", header=[4])
X5 = pd.read_csv('D_R_'+str(5)+'_'+str(2)+'.txt', sep="\t", header=[4])
X6 = pd.read_csv('L_R_'+str(5)+'_'+str(2)+'.txt', sep="\t", header=[4])

ubrz = ((abs(X1['FreeAcc_X']) + abs(X2['FreeAcc_X']) + abs(X3['FreeAcc_X']) + abs(X4['FreeAcc_X']))/4).tolist()
a_x_2[7] = max(ubrz) # ubrzanje u smeru trostruke ekstenzije

poz_max = ubrz.index(a_x_2[7]) 
#print(poz_max)

razlika_ugla1 = ((90+X1['Pitch'] - X3['Pitch'])).tolist()
razlika_ugla2 = ((90+X2['Pitch'] - X4['Pitch'])).tolist()

#ugao pre i ugao posle moze se odrediti u odnosu na trenutak maksimalnog ubrzanja
ugao_pre_2[7] = (min(razlika_ugla1[0:poz_max])+min(razlika_ugla2[0:poz_max]))/2
ugao_posle_2[7] = (min(razlika_ugla1[poz_max:len(razlika_ugla1)-1])+min(razlika_ugla2[poz_max:len(razlika_ugla2)-1]))/2

w_2[7] = max(abs(X5['Gyr_Z']-X6['Gyr_Z'])/2) # maksimum ugaone brzine ruke; Z za desnu a -Z za levu ruku

# %%
br = 4 # ispitanik 3 
skok_3 = np.array([186, 190, 181, 191, 185, 174, 198,  195]) # skokovi ispitanika broj 3
skok_red_3 = skok_3;
skok_3 = skok_3.transpose()
j = 0
rb_3 = [0] * 8 #redni broj skoka
a_x_3 = [0] * 8
w_3 = [0] * 8
ugao_pre_3 = [0] * 8 # ugao savijanja pre skoka
ugao_posle_3 = [0] * 8 # ugao pri doskoku


# dodavanje podatak van petlje zbog odredjenih nekonzistentnosti pri pamcenju podataka

X1 = pd.read_csv('D_B_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X2 = pd.read_csv('L_B_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X3 = pd.read_csv('D_L_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X4 = pd.read_csv('L_L_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X5 = pd.read_csv('D_R_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X6 = pd.read_csv('L_R_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
ubrz = ((abs(X1['FreeAcc_X']) + abs(X2['FreeAcc_X']) + abs(X3['FreeAcc_X']) + abs(X4['FreeAcc_X']))/4).tolist()
a_x_3[0] = max(ubrz) # ubrzanje u smeru trostruke ekstenzije

poz_max = ubrz.index(a_x_3[0]) 
#print(poz_max)

razlika_ugla1 = ((90+X1['Pitch'] - X3['Pitch'])).tolist()
razlika_ugla2 = ((90+X2['Pitch'] - X4['Pitch'])).tolist()

#ugao pre i ugao posle moze se odrediti u odnosu na trenutak maksimalnog ubrzanja
ugao_pre_3[0] = (min(razlika_ugla1[0:poz_max])+min(razlika_ugla2[0:poz_max]))/2
ugao_posle_3[0] = (min(razlika_ugla1[poz_max:len(razlika_ugla1)-1])+min(razlika_ugla2[poz_max:len(razlika_ugla2)-1]))/2

w_3[0] = max(abs(X5['Gyr_Z']-X6['Gyr_Z'])/2) # maksimum ugaone brzine ruke; Z za desnu a -Z za levu ruku


j = 1
for i in range(1,12):
    if (i!=1 and i!=5 and i!=6 and i!=11): # odabir valjanih skokova
        
        rb_3[j] = i

        X1 = pd.read_csv('D_B_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X2 = pd.read_csv('L_B_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X3 = pd.read_csv('D_L_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X4 = pd.read_csv('L_L_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X5 = pd.read_csv('D_R_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X6 = pd.read_csv('L_R_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        ubrz = ((abs(X1['FreeAcc_X']) + abs(X2['FreeAcc_X']) + abs(X3['FreeAcc_X']) + abs(X4['FreeAcc_X']))/4).tolist()
        a_x_3[j] = max(ubrz) # ubrzanje u smeru trostruke ekstenzije
    
        poz_max = ubrz.index(a_x_3[j]) 
        #print(poz_max)
        
        razlika_ugla1 = ((90+X1['Pitch'] - X3['Pitch'])).tolist()
        razlika_ugla2 = ((90+X2['Pitch'] - X4['Pitch'])).tolist()
        
        #ugao pre i ugao posle moze se odrediti u odnosu na trenutak maksimalnog ubrzanja
        ugao_pre_3[j] = (min(razlika_ugla1[0:poz_max])+min(razlika_ugla2[0:poz_max]))/2
        ugao_posle_3[j] = (min(razlika_ugla1[poz_max:len(razlika_ugla1)-1])+min(razlika_ugla2[poz_max:len(razlika_ugla2)-1]))/2
       
        w_3[j] = max(abs(X5['Gyr_Z']-X6['Gyr_Z'])/2) # maksimum ugaone brzine ruke; Z za desnu a -Z za levu ruku
        j = j+1

# %%
br = 5 # ispitanik 4 
skok_4 = np.array([141, 158, 145, 151, 144, 123, 142,  134]) # skokovi ispitanika broj 4
skok_red_4 = skok_4;
skok_4 = skok_4.transpose()
j = 0
rb_4 = [0] * 8 #redni broj skoka
a_x_4 = [0] * 8
w_4 = [0] * 8
ugao_pre_4 = [0] * 8 # ugao savijanja pre skoka
ugao_posle_4 = [0] * 8 # ugao pri doskoku

# dodavanje podatak van petlje zbog odredjenih nekonzistentnosti pri pamcenju podataka

X1 = pd.read_csv('D_B_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X2 = pd.read_csv('L_B_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X3 = pd.read_csv('D_L_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X4 = pd.read_csv('L_L_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X5 = pd.read_csv('D_R_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
X6 = pd.read_csv('L_R_'+str(br)+'_'+str(12)+'.txt', sep="\t", header=[4])
ubrz = ((abs(X1['FreeAcc_X']) + abs(X2['FreeAcc_X']) + abs(X3['FreeAcc_X']) + abs(X4['FreeAcc_X']))/4).tolist()
a_x_4[0] = max(ubrz) # ubrzanje u smeru trostruke ekstenzije

poz_max = ubrz.index(a_x_4[0]) 
#print(poz_max)

razlika_ugla1 = ((90+X1['Pitch'] - X3['Pitch'])).tolist()
razlika_ugla2 = ((90+X2['Pitch'] - X4['Pitch'])).tolist()

#ugao pre i ugao posle moze se odrediti u odnosu na trenutak maksimalnog ubrzanja
ugao_pre_4[0] = (min(razlika_ugla1[0:poz_max])+min(razlika_ugla2[0:poz_max]))/2
ugao_posle_4[0] = (min(razlika_ugla1[poz_max:len(razlika_ugla1)-1])+min(razlika_ugla2[poz_max:len(razlika_ugla2)-1]))/2

w_4[0] = max(abs(X5['Gyr_Z']-X6['Gyr_Z'])/2) # maksimum ugaone brzine ruke; Z za desnu a -Z za levu ruku


j = 1
for i in range(1,12):
    if (i!=1 and i!=2 and i!=4 and i!=5): # odabir valjanih skokova
        rb_4[j] = i
        
        X1 = pd.read_csv('D_B_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X2 = pd.read_csv('L_B_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X3 = pd.read_csv('D_L_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X4 = pd.read_csv('L_L_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X5 = pd.read_csv('D_R_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        X6 = pd.read_csv('L_R_'+str(br)+'_'+str(i)+'.txt', sep="\t", header=[4])
        ubrz = ((abs(X1['FreeAcc_X']) + abs(X2['FreeAcc_X']) + abs(X3['FreeAcc_X']) + abs(X4['FreeAcc_X']))/4).tolist()
        a_x_4[j] = max(ubrz) # ubrzanje u smeru trostruke ekstenzije
    
        poz_max = ubrz.index(a_x_4[j]) 
        #print(poz_max)
        
        razlika_ugla1 = ((90+X1['Pitch'] - X3['Pitch'])).tolist()
        razlika_ugla2 = ((90+X2['Pitch'] - X4['Pitch'])).tolist()
        
        #ugao pre i ugao posle moze se odrediti u odnosu na trenutak maksimalnog ubrzanja
        ugao_pre_4[j] = (min(razlika_ugla1[0:poz_max])+min(razlika_ugla2[0:poz_max]))/2
        ugao_posle_4[j] = (min(razlika_ugla1[poz_max:len(razlika_ugla1)-1])+min(razlika_ugla2[poz_max:len(razlika_ugla2)-1]))/2
       
        w_4[j] = max(abs(X5['Gyr_Z']-X6['Gyr_Z'])/2) # maksimum ugaone brzine ruke; Z za desnu a -Z za levu ruku
        j = j+1

# %%
# provera podataka sa MTw Awinda senzora
skok =  skok_2.tolist() + skok_3.tolist() + skok_4.tolist()
a_x =  a_x_2 + a_x_3 + a_x_4
w =  w_2 + w_3 + w_4
ugao_pre =  ugao_pre_2 + ugao_pre_3 + ugao_pre_4
ugao_posle =  ugao_posle_2 + ugao_posle_3 + ugao_posle_4

# %%
# provera podataka sa MTw Awinda senzora
d = {'Skok':skok,'Ubrzanje':a_x,'Ugaona_brzina':w,'Ugao_pre':ugao_pre,'Ugao_posle':ugao_posle}
df = pd.DataFrame(d)
print(df)

# %%
#formiranje parametara vezanih za EMG signale na osnovu fajlova dobijenih obradom u programskom paketu MATLAB za ispitanika 2

j=0
br = 3
list_unutra_1 = [0] * 8 
list_spolja_1 = [0] * 8
butina_unutra_1 = [0] * 8 
butina_spolja_1 = [0] * 8
loza_unutra_1 = [0] * 8 
loza_spolja_1 = [0] * 8
preklapanje_ldbs_1 = [0] * 8
preklapanje_ldbu_1 = [0] * 8
preklapanje_ldlu_1 = [0] * 8
preklapanje_ldls_1 = [0] * 8
preklapanje_ldzs_1 = [0] * 8
preklapanje_ldzu_1 = [0] * 8
preklapanje_lbz_1 = [0] * 8
preklapanje_dbz_1 = [0] * 8
preklapanje_lbl_1 = [0] * 8
preklapanje_dbl_1 = [0] * 8

for i in range(1,12):
    if (i!=1 and i!=3 and i!=5 and i!=6 and i!=11): # odabir valjanih skokova 
        
        X = pd.read_csv('frekvencije_ispitanik_'+str(br)+'.csv')
        
        list_unutra_1[j] = X.iloc[j,0]
        list_spolja_1[j] = X.iloc[j,1]
        butina_unutra_1[j] = X.iloc[j,2]
        butina_spolja_1[j] = X.iloc[j,3]
        loza_unutra_1[j] = X.iloc[j,4]
        loza_spolja_1[j] = X.iloc[j,5]
        
        X = pd.read_csv('preklapanja_ispitanik_'+str(br)+'.csv')
        preklapanje_ldbs_1[j] = X.iloc[j,0]
        preklapanje_ldbu_1[j] = X.iloc[j,1]
        preklapanje_ldzs_1[j] = X.iloc[j,2]
        preklapanje_ldzu_1[j] = X.iloc[j,3]
        preklapanje_ldls_1[j] = X.iloc[j,4]
        preklapanje_ldlu_1[j] = X.iloc[j,5]
        
        preklapanje_lbz_1[j] = (X.iloc[j,6] + X.iloc[j,7] + X.iloc[j,8] + X.iloc[j,9])/4
        preklapanje_dbz_1[j] = (X.iloc[j,10] + X.iloc[j,11] + X.iloc[j,12] + X.iloc[j,13])/4
        preklapanje_lbl_1[j] = (X.iloc[j,14] + X.iloc[j,15] + X.iloc[j,16] + X.iloc[j,17])/4
        preklapanje_dbl_1[j] = (X.iloc[j,18] + X.iloc[j,19] + X.iloc[j,20] + X.iloc[j,21])/4
        
        j = j+1
        
# dodavanje podatak van petlje zbog odredjenih nekonzistentnosti pri pamcenju podataka

X = pd.read_csv('frekvencije_ispitanik_4'+'.csv')       
list_unutra_1[6] = X.iloc[4,0]
list_spolja_1[6] = X.iloc[4,1]
butina_unutra_1[6] = X.iloc[4,2]
butina_spolja_1[6] = X.iloc[4,3]
loza_unutra_1[6] = X.iloc[4,4]
loza_spolja_1[6] = X.iloc[4,5]

X = pd.read_csv('preklapanja_ispitanik_'+str(4)+'.csv')
preklapanje_ldbs_1[6] = X.iloc[4,0]
preklapanje_ldbu_1[6] = X.iloc[4,1]
preklapanje_ldzs_1[6] = X.iloc[4,2]
preklapanje_ldzu_1[6] = X.iloc[4,3]
preklapanje_ldls_1[6] = X.iloc[4,4]
preklapanje_ldlu_1[6] = X.iloc[4,5]
preklapanje_lbz_1[6] = (X.iloc[4,6] + X.iloc[4,7] + X.iloc[4,8] + X.iloc[4,9])/4
preklapanje_dbz_1[6] = (X.iloc[4,10] + X.iloc[4,11] + X.iloc[4,12] + X.iloc[4,13])/4
preklapanje_lbl_1[6] = (X.iloc[4,14] + X.iloc[4,15] + X.iloc[4,16] + X.iloc[4,17])/4
preklapanje_dbl_1[6] = (X.iloc[4,18] + X.iloc[4,19] + X.iloc[4,20] + X.iloc[4,21])/4

X = pd.read_csv('frekvencije_ispitanik_5'+'.csv')       
list_unutra_1[7] = X.iloc[1,0]
list_spolja_1[7] = X.iloc[1,1]
butina_unutra_1[7] = X.iloc[1,2]
butina_spolja_1[7] = X.iloc[1,3]
loza_unutra_1[7] = X.iloc[1,4]
loza_spolja_1[7] = X.iloc[1,5]

X = pd.read_csv('preklapanja_ispitanik_'+str(5)+'.csv')
preklapanje_ldbs_1[7] = X.iloc[1,0]
preklapanje_ldbu_1[7] = X.iloc[1,1]
preklapanje_ldzs_1[7] = X.iloc[1,2]
preklapanje_ldzu_1[7] = X.iloc[1,3]
preklapanje_ldls_1[7] = X.iloc[1,4]
preklapanje_ldlu_1[7] = X.iloc[1,5]
preklapanje_lbz_1[7] = (X.iloc[1,6] + X.iloc[1,7] + X.iloc[1,8] + X.iloc[1,9])/4
preklapanje_dbz_1[7] = (X.iloc[1,10] + X.iloc[1,11] + X.iloc[1,12] + X.iloc[1,13])/4
preklapanje_lbl_1[7] = (X.iloc[1,14] + X.iloc[1,15] + X.iloc[1,16] + X.iloc[1,17])/4
preklapanje_dbl_1[7] = (X.iloc[1,18] + X.iloc[1,19] + X.iloc[1,20] + X.iloc[1,21])/4

# %%
#formiranje parametara vezanih za EMG signale na osnovu fajlova dobijenih obradom u programskom paketu MATLAB za ispitanika 3

j=0
br = 4
list_unutra_2 = [0] * 8 
list_spolja_2 = [0] * 8
butina_unutra_2 = [0] * 8 
butina_spolja_2 = [0] * 8
loza_unutra_2 = [0] * 8 
loza_spolja_2 = [0] * 8
preklapanje_ldbs_2 = [0] * 8
preklapanje_ldbu_2 = [0] * 8
preklapanje_ldlu_2 = [0] * 8
preklapanje_ldls_2 = [0] * 8
preklapanje_ldzs_2 = [0] * 8
preklapanje_ldzu_2 = [0] * 8
preklapanje_lbz_2 = [0] * 8
preklapanje_dbz_2 = [0] * 8
preklapanje_lbl_2 = [0] * 8
preklapanje_dbl_2 = [0] * 8

for i in range(1,12):
    if (i!=5 and i!=6 and i!=11): # odabir valjanih skokova
        
        X = pd.read_csv('frekvencije_ispitanik_'+str(br)+'.csv')
        
        list_unutra_2[j] = X.iloc[j,0]
        list_spolja_2[j] = X.iloc[j,1]
        butina_unutra_2[j] = X.iloc[j,2]
        butina_spolja_2[j] = X.iloc[j,3]
        loza_unutra_2[j] = X.iloc[j,4]
        loza_spolja_2[j] = X.iloc[j,5]
        
        X = pd.read_csv('preklapanja_ispitanik_'+str(br)+'.csv')
        preklapanje_ldbs_2[j] = X.iloc[j,0]
        preklapanje_ldbu_2[j] = X.iloc[j,1]
        preklapanje_ldzs_2[j] = X.iloc[j,2]
        preklapanje_ldzu_2[j] = X.iloc[j,3]
        preklapanje_ldls_2[j] = X.iloc[j,4]
        preklapanje_ldlu_2[j] = X.iloc[j,5]
        
        preklapanje_lbz_2[j] = (X.iloc[j,6] + X.iloc[j,7] + X.iloc[j,8] + X.iloc[j,9])/4
        preklapanje_dbz_2[j] = (X.iloc[j,10] + X.iloc[j,11] + X.iloc[j,12] + X.iloc[j,13])/4
        preklapanje_lbl_2[j] = (X.iloc[j,14] + X.iloc[j,15] + X.iloc[j,16] + X.iloc[j,17])/4
        preklapanje_dbl_2[j] = (X.iloc[j,18] + X.iloc[j,19] + X.iloc[j,20] + X.iloc[j,21])/4
        
        j = j+1

# %%
#formiranje parametara vezanih za EMG signale na osnovu fajlova dobijenih obradom u programskom paketu MATLAB za ispitanika 4

j=0
br = 5
list_unutra_3 = [0] * 8 
list_spolja_3 = [0] * 8
butina_unutra_3 = [0] * 8 
butina_spolja_3 = [0] * 8
loza_unutra_3 = [0] * 8 
loza_spolja_3 = [0] * 8
preklapanje_ldbs_3 = [0] * 8
preklapanje_ldbu_3 = [0] * 8
preklapanje_ldlu_3 = [0] * 8
preklapanje_ldls_3 = [0] * 8
preklapanje_ldzs_3 = [0] * 8
preklapanje_ldzu_3 = [0] * 8
preklapanje_lbz_3 = [0] * 8
preklapanje_dbz_3 = [0] * 8
preklapanje_lbl_3 = [0] * 8
preklapanje_dbl_3 = [0] * 8

for i in range(1,12):
    if (i!=2 and i!=4 and i!=5): # odabir valjanih skokova
        
        X = pd.read_csv('frekvencije_ispitanik_'+str(br)+'.csv')
        
        list_unutra_3[j] = X.iloc[j,0]
        list_spolja_3[j] = X.iloc[j,1]
        butina_unutra_3[j] = X.iloc[j,2]
        butina_spolja_3[j] = X.iloc[j,3]
        loza_unutra_3[j] = X.iloc[j,4]
        loza_spolja_3[j] = X.iloc[j,5]
        
        X = pd.read_csv('preklapanja_ispitanik_'+str(br)+'.csv')
        preklapanje_ldbs_3[j] = X.iloc[j,0]
        preklapanje_ldbu_3[j] = X.iloc[j,1]
        preklapanje_ldzs_3[j] = X.iloc[j,2]
        preklapanje_ldzu_3[j] = X.iloc[j,3]
        preklapanje_ldls_3[j] = X.iloc[j,4]
        preklapanje_ldlu_3[j] = X.iloc[j,5]
        
        preklapanje_lbz_3[j] = (X.iloc[j,6] + X.iloc[j,7] + X.iloc[j,8] + X.iloc[j,9])/4
        preklapanje_dbz_3[j] = (X.iloc[j,10] + X.iloc[j,11] + X.iloc[j,12] + X.iloc[j,13])/4
        preklapanje_lbl_3[j] = (X.iloc[j,14] + X.iloc[j,15] + X.iloc[j,16] + X.iloc[j,17])/4
        preklapanje_dbl_3[j] = (X.iloc[j,18] + X.iloc[j,19] + X.iloc[j,20] + X.iloc[j,21])/4
        
        j = j+1

# %%
#formiranje listi za pamcenje parametara

list_unutra = list_unutra_1 + list_unutra_2 + list_unutra_3
list_spolja = list_spolja_1 + list_spolja_2 + list_spolja_3
butina_unutra =  butina_unutra_1 + butina_unutra_2 + butina_unutra_3
butina_spolja = butina_spolja_1 + butina_spolja_2 + butina_spolja_3
loza_unutra = loza_unutra_1 + loza_unutra_2 + loza_unutra_3 
loza_spolja = loza_spolja_1 + loza_spolja_2 + loza_spolja_3
preklapanje_ldbs = preklapanje_ldbs_1 + preklapanje_ldbs_2 + preklapanje_ldbs_3 
preklapanje_ldbu = preklapanje_ldbu_1 + preklapanje_ldbu_2 + preklapanje_ldbu_3 
preklapanje_ldlu = preklapanje_ldlu_1 + preklapanje_ldlu_2 + preklapanje_ldlu_3
preklapanje_ldls = preklapanje_ldls_1 + preklapanje_ldls_2 + preklapanje_ldls_3
preklapanje_ldzs = preklapanje_ldzs_1 + preklapanje_ldzs_2 + preklapanje_ldzs_3
preklapanje_ldzu = preklapanje_ldzu_1 + preklapanje_ldzu_2 + preklapanje_ldzu_3
preklapanje_lbz = preklapanje_lbz_1 + preklapanje_lbz_2 + preklapanje_lbz_3
preklapanje_dbz = preklapanje_dbz_1 + preklapanje_dbz_2 + preklapanje_dbz_3
preklapanje_lbl = preklapanje_lbl_1 + preklapanje_lbl_2 + preklapanje_lbl_3
preklapanje_dbl = preklapanje_dbl_1 + preklapanje_dbl_2 + preklapanje_dbl_3

# %%
# provera duzina lista

print(len(skok))

print(len(list_unutra))

# %%
# formiranja DataFrame-a sa svim podacima

d = {'Skok':skok,'Ubrzanje':a_x,'Ugaona_brzina':w,'Ugao_pre':ugao_pre,'Ugao_posle':ugao_posle,'Frek_gastrocnemius_medialis':list_unutra,'Frek_gastrocnemius_lateralis':list_spolja,'Frek_vastus_medialis':butina_unutra,'Frek_vastus_lateralis':butina_spolja,'Frek_semitendinosus':loza_unutra,'Frek_biceps_femoris':loza_spolja,'Preklapanje_vastus_lateralis':preklapanje_ldbs,'Preklapanje_vastus_medialis':preklapanje_ldbu,'Preklapanje_gastrocnemius_medialis':preklapanje_ldlu,'Preklapanje_gastrocnemius_lateralis':preklapanje_ldls,'Preklapanje_semitendinosus':preklapanje_ldzu,'Preklapanje_biceps_femoris':preklapanje_ldzs,'Preklapanje_butina_loza_leva':preklapanje_lbz,'Preklapanje_butina_loza_desna':preklapanje_dbz,'Preklapanje_butina_list_levi':preklapanje_lbl,'Preklapanje_butina_list_desni':preklapanje_dbl}
df = pd.DataFrame(d)
print(df)

# %%
x = df['Ugaona_brzina']
y = df['Skok']

plt.figure()
plt.scatter(x,y)
plt.xlabel('Ugaona brzina [rad/s]')
plt.ylabel('Distanca skoka [cm]')
plt.grid()

# %%
x = df['Ubrzanje']
y = df['Skok']

plt.figure()
plt.scatter(x,y)
plt.xlabel('Ubrzanje [m/s^2]')
plt.ylabel('Distanca skoka [cm]')
plt.grid()

# %%
x = df['Ugao_pre']
y = df['Skok']

plt.figure()
plt.scatter(x,y)
plt.xlabel('Ugao [°]')
plt.ylabel('Distanca skoka [cm]')
plt.grid()

# %%
x = df['Ugao_posle']
y = df['Skok']

plt.figure()
plt.scatter(x,y)
plt.xlabel('Ugao [°]')
plt.ylabel('Distanca skoka [cm]')
plt.grid()

# %%
sr_mae = 0
i = 1
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
i = 2
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
i = 3
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
i = 4
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
i = 5
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
# ispis srednje MAE
sr_mae = sr_mae/5
print(sr_mae)
print(min(skok))
print(max(skok))

# %%
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)
shap.summary_plot(shap_values, X)

# %%
shap.dependence_plot('Ugao_pre', shap_values, X)

# %%
#crtanje skokova
lst = []
for i in range(1,25):
    lst.append(i)


plt.figure(1)
plt.scatter(lst,skok)
plt.xlabel('Skok')
plt.ylabel('Distanca [cm]')
plt.grid()

# %%
#uzimanje samo MTw Awinda podataka
selected_columns = df[["Skok","Ubrzanje","Ugaona_brzina","Ugao_pre","Ugao_posle"]]

df = selected_columns.copy()
print(df)

# %%
#treniranje i testiranje sa samo MTw Awinda podacima
sr_mae = 0
i = 1
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
i = 2
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
i = 3
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
i = 4
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
i = 5
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25, random_state=i, shuffle=True) 
target = 'Skok'
# za XGBoost
y_train, y_test = train[target].values, test[target].values
X_train, X_test = train.loc[:, train.columns != target], test.loc[:, test.columns != target]


import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)
from sklearn.metrics import mean_absolute_error

# kros validacija na trening podacima za odabir najboljih parametara ucenja
mean_train = np.mean(y_train)
baseline_predictions = np.ones(y_test.shape) * mean_train
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
params = {
    # Parametri za podesavanje sa nekim inicijalnim vrenostima
    'max_depth':10,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Ostali parametri
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,10)
    for min_child_weight in range(1,5)
]
n_fold = 6
early_str = 20

#azuriranje parametara
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:



    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight

    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics = {'mae'},
        early_stopping_rounds = early_str
    )

    # Azuriranje najbolje MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)

params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_mae = float("Inf")
best_params = None

for subsample, colsample in reversed(gridsearch_params):



    params['subsample'] = subsample
    params['colsample_bytree'] = colsample


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics={'mae'},
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    #print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)

params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

min_mae = float("Inf")
best_params = None

for eta in [.5, .3, .2, .1, .05, .01, .005]:



    params['eta'] = eta


    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round = num_boost_round,
        seed = 42,
        nfold = n_fold,
        metrics=['mae'],
        early_stopping_rounds = early_str
    )

    # azuriranje najboljeg rezultata
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].values.argmin()
    #print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta

params['eta'] = best_params
params

#treniranje modela
model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

num_boost_round = model.best_iteration + 1

best_model = xgb.train(
    params,
    dtrain,
    num_boost_round = num_boost_round,
    evals = [(dtest, "Test")]
)


#interpretiranje rezultata
import shap
shap.initjs()
X = df.loc[:, df.columns != target]

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

#radjenje predikcije i crtanje uporedo grafika stvarnih i prediktovanih vrednosti i njihovih razlika
predikcije1 = best_model.predict(dtest).tolist()
predikcije = predikcije1# + predikcije2


plt.figure((i-1)*5+1)
plt.plot(predikcije)
plt.plot(test.loc[:,  target].tolist())
plt.xlabel('Skok iz test podataka')
plt.ylabel('Distanca [cm]')
plt.legend(['Predikcija','Merenje'])
plt.grid()

razlika = [0] * 6
for i in range(0,6):
    razlika[i] = test.loc[:,  target].tolist()[i] - predikcije[i]

plt.figure((i-1)*5+2)
plt.plot(razlika)
plt.xlabel('Skok iz test podataka')
plt.ylabel('Odstupanje predikcije [cm]')
plt.grid()

#racunanje MAE
mae = 0 
for i in range(len(razlika)):
    mae = mae + abs(razlika[i])
mae = mae/6
print(mae)
sr_mae = sr_mae + mae

# %%
# ispis srednje MAE
sr_mae = sr_mae/5
print(sr_mae)
print(min(skok))
print(max(skok))
